# %% [markdown]
# <a href="https://colab.research.google.com/github/JOSEDUARDOCABRERAPEGUEROS/Probabilidad-Y-Estad-stica/blob/main/Practica%204%20y%205.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![ITD LOGO.jfif](data:image/jpeg;base64,...)

# %% [markdown]
# # Probabilidad y estadistica
# unidad 1
#
# Grupo: 2z
#
# Practica 4 y 5. Tabla de frecuencias y regla de Sturges, Diagramas de Cajas y bigotes.
#
# Alumno:José Eduardo Cabrera Pegueros
#
# Docente: Dr: Jose Gabriel Rodriguez Rivas

# %%
import random
#Creamos una lista vacia de 100 personas
edades = []

for i in range (100):
  #ciclo para generar 100 numeros aleatoriosque representan las edades
  numero_aleatorio = random.randint( 18, 70)
  #agregamos ell numero aleatorio a la lista de valores
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [57, 44, 37, 26, 26, 37, 23, 49, 50, 56, 51, 59, 31, 47, 40, 24, 42, 31, 33, 60, 60, 18, 46, 29, 34, 65, 43, 27, 45, 58, 64, 19, 31, 52, 44, 45, 34, 56, 49, 45, 39, 28, 56, 30, 70, 28, 22, 38, 27, 48, 27, 31, 29, 41, 45, 48, 67, 47, 35, 63, 59, 50, 31, 45, 23, 36, 66, 59, 64, 36, 63, 60, 19, 61, 32, 44, 18, 68, 68, 40, 18, 46, 33, 37, 26, 70, 64, 34, 63, 33, 34, 41, 39, 32, 24, 24, 37, 59, 58, 51]

# %%
import pandas as pd
df = pd.DataFrame(edades,columns =['Edad'])
df.head()
# Out:
#    Edad
# 0    57
# 1    44
# 2    37
# 3    26
# 4    26

# %%
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad','Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')
print("Tabla de la Distribucion de frecuencias: ")
tabla_frecuencias
# Out:
# Tabla de la Distribucion de frecuencias:
#     Edad  Frecuencia
# 13    18           3
# 17    19           2
# 39    22           1
# 31    23           2
# 12    24           3
# 7     26           3
# 10    27           3
# 22    28           2
# 24    29           2
# 40    30           1
# 1     31           5
# 25    32           2
# 14    33           3
# 3     34           4
# 36    35           1
# 19    36           2
# 2     37           4
# 38    38           1
# 18    39           2
# 26    40           2
# 32    41           2
# 43    42           1
# 44    43           1
# 5     44           3
# 0     45           5
# 23    46           2
# 27    47           2
# 21    48           2
# 30    49           2
# 29    50           2
# 28    51           2
# 41    52           1
# 9     56           3
# 37    57           1
# 15    58           2
# 4     59           4
# 6     60           3
# 33    61           1
# 8     63           3
# 11    64           3
# 42    65           1
# 35    66           1
# 34    67           1
# 16    68           2
# 20    70           2

# %%
tabla_frecuencias['Frec relativa'] = tabla_frecuencias['Frecuencia']/100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec relativa
# 13    18           3           0.03
# 17    19           2           0.02
# 39    22           1           0.01
# 31    23           2           0.02
# 12    24           3           0.03
# 7     26           3           0.03
# 10    27           3           0.03
# 22    28           2           0.02
# 24    29           2           0.02
# 40    30           1           0.01
# 1     31           5           0.05
# 25    32           2           0.02
# 14    33           3           0.03
# 3     34           4           0.04
# 36    35           1           0.01
# 19    36           2           0.02
# 2     37           4           0.04
# 38    38           1           0.01
# 18    39           2           0.02
# 26    40           2           0.02
# 32    41           2           0.02
# 43    42           1           0.01
# 44    43           1           0.01
# 5     44           3           0.03
# 0     45           5           0.05
# 23    46           2           0.02
# 27    47           2           0.02
# 21    48           2           0.02
# 30    49           2           0.02
# 29    50           2           0.02
# 28    51           2           0.02
# 41    52           1           0.01
# 9     56           3           0.03
# 37    57           1           0.01
# 15    58           2           0.02
# 4     59           4           0.04
# 6     60           3           0.03
# 33    61           1           0.01
# 8     63           3           0.03
# 11    64           3           0.03
# 42    65           1           0.01
# 35    66           1           0.01
# 34    67           1           0.01
# 16    68           2           0.02
# 20    70           2           0.02

# %%
tabla_frecuencias['Frec porcentual'] = tabla_frecuencias['Frecuencia']/100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec relativa  Frec porcentual
# 13    18           3           0.03             0.03
# 17    19           2           0.02             0.02
# 39    22           1           0.01             0.01
# 31    23           2           0.02             0.02
# 12    24           3           0.03             0.03
# 7     26           3           0.03             0.03
# 10    27           3           0.03             0.03
# 22    28           2           0.02             0.02
# 24    29           2           0.02             0.02
# 40    30           1           0.01             0.01
# 1     31           5           0.05             0.05
# 25    32           2           0.02             0.02
# 14    33           3           0.03             0.03
# 3     34           4           0.04             0.04
# 36    35           1           0.01             0.01
# 19    36           2           0.02             0.02
# 2     37           4           0.04             0.04
# 38    38           1           0.01             0.01
# 18    39           2           0.02             0.02
# 26    40           2           0.02             0.02
# 32    41           2           0.02             0.02
# 43    42           1           0.01             0.01
# 44    43           1           0.01             0.01
# 5     44           3           0.03             0.03
# 0     45           5           0.05             0.05
# 23    46           2           0.02             0.02
# 27    47           2           0.02             0.02
# 21    48           2           0.02             0.02
# 30    49           2           0.02             0.02
# 29    50           2           0.02             0.02
# 28    51           2           0.02             0.02
# 41    52           1           0.01             0.01
# 9     56           3           0.03             0.03
# 37    57           1           0.01             0.01
# 15    58           2           0.02             0.02
# 4     59           4           0.04             0.04
# 6     60           3           0.03             0.03
# 33    61           1           0.01             0.01
# 8     63           3           0.03             0.03
# 11    64           3           0.03             0.03
# 42    65           1           0.01             0.01
# 35    66           1           0.01             0.01
# 34    67           1           0.01             0.01
# 16    68           2           0.02             0.02
# 20    70           2           0.02             0.02

# %%
tabla_frecuencias['Frec Acumulada'] = tabla_frecuencias['Frecuencia']. cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec relativa  Frec porcentual  Frec Acumulada
# 13    18           3           0.03             0.03               3
# 17    19           2           0.02             0.02               5
# 39    22           1           0.01             0.01               6
# 31    23           2           0.02             0.02               8
# 12    24           3           0.03             0.03              11
# 7     26           3           0.03             0.03              14
# 10    27           3           0.03             0.03              17
# 22    28           2           0.02             0.02              19
# 24    29           2           0.02             0.02              21
# 40    30           1           0.01             0.01              22
# 1     31           5           0.05             0.05              27
# 25    32           2           0.02             0.02              29
# 14    33           3           0.03             0.03              32
# 3     34           4           0.04             0.04              36
# 36    35           1           0.01             0.01              37
# 19    36           2           0.02             0.02              39
# 2     37           4           0.04             0.04              43
# 38    38           1           0.01             0.01              44
# 18    39           2           0.02             0.02              46
# 26    40           2           0.02             0.02              48
# 32    41           2           0.02             0.02              50
# 43    42           1           0.01             0.01              51
# 44    43           1           0.01             0.01              52
# 5     44           3           0.03             0.03              55
# 0     45           5           0.05             0.05              60
# 23    46           2           0.02             0.02              62
# 27    47           2           0.02             0.02              64
# 21    48           2           0.02             0.02              66
# 30    49           2           0.02             0.02              68
# 29    50           2           0.02             0.02              70
# 28    51           2           0.02             0.02              72
# 41    52           1           0.01             0.01              73
# 9     56           3           0.03             0.03              76
# 37    57           1           0.01             0.01              77
# 15    58           2           0.02             0.02              79
# 4     59           4           0.04             0.04              83
# 6     60           3           0.03             0.03              86
# 33    61           1           0.01             0.01              87
# 8     63           3           0.03             0.03              90
# 11    64           3           0.03             0.03              93
# 42    65           1           0.01             0.01              94
# 35    66           1           0.01             0.01              95
# 34    67           1           0.01             0.01              96
# 16    68           2           0.02             0.02              98
# 20    70           2           0.02             0.02             100

# %%
#Libreria para calculos matematicos
import math
print (edades)
# Out:
# [57, 44, 37, 26, 26, 37, 23, 49, 50, 56, 51, 59, 31, 47, 40, 24, 42, 31, 33, 60, 60, 18, 46, 29, 34, 65, 43, 27, 45, 58, 64, 19, 31, 52, 44, 45, 34, 56, 49, 45, 39, 28, 56, 30, 70, 28, 22, 38, 27, 48, 27, 31, 29, 41, 45, 48, 67, 47, 35, 63, 59, 50, 31, 45, 23, 36, 66, 59, 64, 36, 63, 60, 19, 61, 32, 44, 18, 68, 68, 40, 18, 46, 33, 37, 26, 70, 64, 34, 63, 33, 34, 41, 39, 32, 24, 24, 37, 59, 58, 51]

# %%
#generar un nuevo dataFrame con las edades
import pandas as pd
df = pd.DataFrame({'Edad':edades})
df
# Out:
#     Edad
# 0     57
# 1     44
# 2     37
# 3     26
# 4     26
# ..   ...
# 95    24
# 96    37
# 97    59
# 98    58
# 99    51
#
# [100 rows x 1 columns]

# %%
n = len (edades)
k = int (1 + math.log2(100))
print ("Valor de n = ",n, "\nNumero de intervalos =",k)
# Out:
# Valor de n =  100
# Numero de intervalos = 7

# %%
tabla_frecuencias = pd.cut (df['Edad'], bins=k, include_lowest=True).value_counts().reset_index()
tabla_frecuencias.columns = ['clase','frec']
tabla_frecuencias
# Out:
#               clase  frec
# 0  (32.857, 40.286]    19
# 1  (25.429, 32.857]    18
# 2  (40.286, 47.714]    16
# 3  (55.143, 62.571]    14
# 4    (62.571, 70.0]    13
# 5  (17.947, 25.429]    11
# 6  (47.714, 55.143]     9

# %%
tabla_frecuencias = tabla_frecuencias.sort_values( by='clase')
tabla_frecuencias
# Out:
#               clase  frec
# 5  (17.947, 25.429]    11
# 1  (25.429, 32.857]    18
# 0  (32.857, 40.286]    19
# 2  (40.286, 47.714]    16
# 6  (47.714, 55.143]     9
# 3  (55.143, 62.571]    14
# 4    (62.571, 70.0]    13

# %%
tabla_frecuencias['frec Rel']= tabla_frecuencias['frec']/n
tabla_frecuencias['frec Porc']= tabla_frecuencias['frec']/n* 100
tabla_frecuencias['frec Ac']= tabla_frecuencias['frec'].cumsum()
tabla_frecuencias['frec Rel Ac']= tabla_frecuencias['frec Porc'].cumsum()
tabla_frecuencias['frec Porc Ac']= tabla_frecuencias['frec Porc'].cumsum()
print("Tabla de frecuencias: ")
tabla_frecuencias
# Out:
# Tabla de frecuencias:
#               clase  frec  frec Rel  frec Porc  frec Ac  frec Rel Ac  \
# 5  (17.947, 25.429]    11      0.11       11.0       11         11.0
# 1  (25.429, 32.857]    18      0.18       18.0       29         29.0
# 0  (32.857, 40.286]    19      0.19       19.0       48         48.0
# 2  (40.286, 47.714]    16      0.16       16.0       64         64.0
# 6  (47.714, 55.143]     9      0.09        9.0       73         73.0
# 3  (55.143, 62.571]    14      0.14       14.0       87         87.0
# 4    (62.571, 70.0]    13      0.13       13.0      100        100.0
#
#    frec Porc Ac
# 5          11.0
# 1          29.0
# 0          48.0
# 2          64.0
# 6          73.0
# 3          87.0
# 4         100.0

# %%
import matplotlib.pyplot as plt
plt.hist(edades,alpha=0.5,bins=20)
plt.title("Histrograma de edades basado en la funcion de matplotib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histrograma de edades basado en la funcion de matplotib con valores estandar')

# %%
plt.hist(df['Edad'],bins=k,alpha=0.5)
plt.title('Histograma de edades basado en la regla de sturges')
plt.xlabel('edades')
plt.xlabel('frecuencia')
# Out:
# Text(0.5, 0, 'frecuencia')

# %% [markdown]
# **Practica 5 Diagrama de cajas y bigotes**

# %%
#Creamos una lista vacia de 100 personas
edades2 = []

for i in range (100):
  #ciclo para generar 100 numeros aleatoriosque representan las edades
  numero_aleatorio = random.randint( 20, 87)
  #agregamos ell numero aleatorio a la lista de valores
  edades2.append(numero_aleatorio)
print(edades2)
# Out:
# [77, 55, 24, 85, 64, 26, 57, 45, 49, 49, 24, 62, 30, 60, 20, 68, 55, 57, 29, 76, 30, 48, 37, 71, 20, 83, 62, 77, 80, 69, 34, 81, 69, 65, 77, 78, 56, 31, 79, 20, 31, 36, 61, 45, 48, 33, 35, 79, 23, 44, 37, 72, 57, 23, 80, 62, 82, 41, 61, 40, 69, 22, 58, 81, 83, 67, 56, 44, 44, 65, 70, 51, 67, 35, 33, 83, 53, 58, 35, 39, 74, 50, 30, 71, 30, 59, 79, 63, 83, 71, 47, 37, 44, 32, 27, 77, 82, 54, 53, 57]

# %%
fig, (ax1,ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(edades, vert=True, patch_artist=True)
ax1.set_title('Edades Encuesta 1')

bplot2 = ax2.boxplot(edades2, vert=True, patch_artist=True)
ax2.set_title('Edades Encuesta 2')
plt.show()

# %%
edades2.append(130)

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(edades, vert=True, patch_artist=True)
ax1.set_title('Edades Encuesta 1')

bplot2 = ax2.boxplot(edades2, vert=True, patch_artist=True)
ax2.set_title('Edades Encuesta 2')
plt.show()
